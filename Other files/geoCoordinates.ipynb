# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import json
from pathlib import Path
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['Project3', 'admin', 'classDB', 'config', 'local', 'met', 'uk_food']

# %%
df = pd.read_json("Shark_AttacksDB.Events.json")
#simple_df = df[["Case Number", "Location"]]
#simple_df
df
# Out:
#                                       _id   Case Number       Date  Year  \
# 0    {'$oid': '64b9f9b7cd4dab5c54d1ae7d'}    2018.06.25  25-Jun-18  2018
# 1    {'$oid': '64b9f9b7cd4dab5c54d1ae7e'}    2018.06.18  18-Jun-18  2018
# 2    {'$oid': '64b9f9b7cd4dab5c54d1ae7f'}    2018.06.09   9-Jun-18  2018
# 3    {'$oid': '64b9f9b7cd4dab5c54d1ae81'}    2018.06.04   4-Jun-18  2018
# 4    {'$oid': '64b9f9b7cd4dab5c54d1ae84'}    2018.05.27  27-May-18  2018
# ..                                    ...           ...        ...   ...
# 502  {'$oid': '64b9f9b7cd4dab5c54d1b284'}    2010.04.28  28-Apr-10  2010
# 503  {'$oid': '64b9f9b7cd4dab5c54d1b285'}    2010.04.19  19-Apr-10  2010
# 504  {'$oid': '64b9f9b7cd4dab5c54d1b290'}  2010.02.06.a   6-Feb-10  2010
# 505  {'$oid': '64b9f9b7cd4dab5c54d1b292'}    2010.02.03   3-Feb-10  2010
# 506  {'$oid': '64b9f9b7cd4dab5c54d1b29d'}    2010.01.06   6-Jan-10  2010
#
#            Type Country        Area  \
# 0       Boating     USA  California
# 1    Unprovoked     USA     Georgia
# 2       Invalid     USA      Hawaii
# 3      Provoked  MEXICO      Colima
# 4    Unprovoked     USA     Florida
# ..          ...     ...         ...
# 502    Provoked     USA     Florida
# 503  Unprovoked     USA      Hawaii
# 504    Provoked     USA     Florida
# 505  Unprovoked     USA     Florida
# 506  Unprovoked     USA     Florida
#
#                                               Location               Activity  \
# 0                          Oceanside, San Diego County               Paddling
# 1                       St. Simon Island, Glynn County               Standing
# 2                                         Habush, Oahu                Surfing
# 3                                             La Ticla            Free diving
# 4    Lighhouse Point Park, Ponce Inlet, Volusia County                Fishing
# ..                                                 ...                    ...
# 502                                        Hanalei Bay       Measuring sharks
# 503                                 Hanalei Bay, Kauai                Surfing
# 504                                      Riviera Beach  Surf fishing / wading
# 505                              Stuart, Martin County          Kite Boarding
# 506                                         Elliot Key           Spearfishing
#
#     Sex                                              Injury Fatal (Y/N)  \
# 0      F  No injury to occupant, outrigger canoe and pad...           N
# 1      F                         Minor injury to left thigh           N
# 2      M       Injury to left lower leg from surfboard skeg           N
# 3      M  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# 4      M            Minor injury to foot. PROVOKED INCIDENT           N
# ..   ...                                                ...         ...
# 502    M                      Arm bitten PROVOKED INCIDENT            N
# 503    M                        No injury, surfboard bitten           N
# 504    M  Leg bitten while trying to free a hooked shark...           N
# 505    M                                              FATAL           Y
# 506    M                                Lacerations to  arm           N
#
#                                           href formula
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...
# ..                                                 ...
# 502  http://sharkattackfile.net/spreadsheets/pdf_di...
# 503  http://sharkattackfile.net/spreadsheets/pdf_di...
# 504  http://sharkattackfile.net/spreadsheets/pdf_di...
# 505  http://sharkattackfile.net/spreadsheets/pdf_di...
# 506  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [507 rows x 13 columns]

# %%
for row in df.index:
    print(df["Year"][row])
# Out:
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
geoCoordinates = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in our list to fetch weather data
for row in df.index:
    location = df["Location"][row]
    country = df["Country"][row]

    # Create endpoint URL with each city
    geo_url = f"{url}appid={weather_api_key}&units=metric&q={place}"
    
    # Log the url, record, and set numbers
    print(f"Processing Record %s of Set {location}")

    # Run an API request for each of the cities
    try:

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        #city_weather = requests.get(city_url).json()['weather']
        city_lat = requests.get(geo_url).json()['coord']['lat']
        city_lng = requests.get(geo_url).json()['coord']['lon']

        # Append the City information into city_data list
        geoCoordinates.append({"Case Number": df["Case Number"][row],
                          "Date": df["Date"][row],
                          "Year": str(df["Year"][row]),
                          "Country": df["Country"][row],
                          "Type": df["Type"][row],
                          "Location": df["Location"][row],
                          "Activity": df["Activity"][row],
                          "Injury": df["Injury"][row],
                          "Fatal": df["Fatal (Y/N)"][row],
                          "Link": df["href formula"][row],
                          "Lat": city_lat, 
                          "Lng": city_lng})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record %s of Set Oceanside, San Diego County
# City not found. Skipping...
# Processing Record %s of Set St. Simon Island, Glynn County
# City not found. Skipping...
# Processing Record %s of Set Habush, Oahu
# City not found. Skipping...
# Processing Record %s of Set La Ticla
# City not found. Skipping...
# Processing Record %s of Set Lighhouse Point Park, Ponce Inlet, Volusia County
# City not found. Skipping...
# Processing Record %s of Set Cocoa Beach, Brevard  County
# City not found. Skipping...
# Processing Record %s of Set Daytona Beach, Volusia County
# City not found. Skipping...
# Processing Record %s of Set Isle of Palms,  Charleston County
# City not found. Skipping...
# Processing Record %s of Set Hilton Head Island, Beaufort County
# City not found. Skipping...
# Processing Record %s of Set Shipwreck’s Beach, Keoneloa Bay, Kauai
# City not found. Skipping...
# Processing Record %s of Set Kukio Beach
# City not found. Skipping...
# Processing Record %s of Set Hultin's Beach, Oahu
# City not found. Skipping...
# Processing Record %s of Set Drakes Estero, Point Reyes, Marin County
# City not found. Skipping...
# Processing Record %s of Set Stillwater Cove, Monterey County
# City not found. Skipping...
# Processing Record %s of Set Floridana Beach, Brevard County
# City not found. Skipping...
# Processing Record %s of Set White Plains Beach, Oahu
# City not found. Skipping...
# Processing Record %s of Set Juno Beach, Palm Beach County
# City not found. Skipping...
# Processing Record %s of Set Ocean Reef Park, Singer Island, Palm Beach County
# City not found. Skipping...
# Processing Record %s of Set Lantana Beach, Palm Beach County
# City not found. Skipping...
# Processing Record %s of Set Davidsons Beach, Kekaha, Kauai
# City not found. Skipping...
# Processing Record %s of Set Kama‘ole Beach Park, Maui
# City not found. Skipping...
# Processing Record %s of Set Hanna Park, Jacksonville, Duval County
# City not found. Skipping...
# Processing Record %s of Set Rockaway
# City not found. Skipping...
# Processing Record %s of Set Fort Worth
# City not found. Skipping...
# Processing Record %s of Set Palm Beach County
# City not found. Skipping...
# Processing Record %s of Set Ponce Inlet, Volusia County
# City not found. Skipping...
# Processing Record %s of Set Ponce Inlet, Volusia County
# City not found. Skipping...
# Processing Record %s of Set Marathon, Monroe County
# City not found. Skipping...
# Processing Record %s of Set South Padre Island, Cameron County
# City not found. Skipping...
# Processing Record %s of Set New Smyrna Beach, Volusia County
# City not found. Skipping...
# Processing Record %s of Set Bathtub Beach
# City not found. Skipping...
# Processing Record %s of Set Marconi Beach, Wellfleet, Barnstable County
# City not found. Skipping...
# Processing Record %s of Set Sea Pines Resort, Hilton Head Island, Beaufort County
# City not found. Skipping...
# Processing Record %s of Set Menauhant Beach, Falmouth,
# Barnstable County
# City not found. Skipping...
# Processing Record %s of Set Between Pescadero Point & Bean Hollow Beach, San Mateo County
# City not found. Skipping...
# Processing Record %s of Set Jacksonvlle, Duval County
# City not found. Skipping...
# Processing Record %s of Set Hilton Head Island, Beaufort County
# City not found. Skipping...
# Processing Record %s of
# City not found. Skipping...
# Processing Record %s of Set New Smyrna Beach
# City not found. Skipping...
# Processing Record %s of Set Galveston
# City not found. Skipping...
# Processing Record %s of Set Lauderdale-by-the-Sea, Broward County
# City not found. Skipping...
# Processing Record %s of Set Off Long Island
# City not found. Skipping...
# Processing Record %s of Set Pismo Beach, San Luis  Obispo County
# City not found. Skipping...
# Processing Record %s of Set Dog Patch, San Onofre
# City not found. Skipping...
# Processing Record %s of Set Eight Mile Beach, Galveston
# City not found. Skipping...
# Processing Record %s of Set Fripp Island
# City not found. Skipping...
# Processing Record %s of Set Topsail Island, Pender County
# City not found. Skipping...
# Processing Record %s of Set Jacksonville
# City not found. Skipping...
# Processing Record %s of Set Ponte Vedra Beach, St Johns County
# City not found. Skipping...
# Processing Record %s of Set Off Tarpon Springs
# City not found. Skipping...
# Processing Record %s of Set New Smyrna Beach
# City not found. Skipping...
# Processing Record %s of Set Hanalei Bay
# City not found. Skipping...
# Processing Record %s of Set Hanalei Bay, Kauai
# City not found. Skipping...
# Processing Record %s of Set Riviera Beach
# City not found. Skipping...
# Processing Record %s of Set Stuart, Martin County
# City not found. Skipping...
# Processing Record %s of Set Elliot Key
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
pprint(geoCoordinates)
# Out:
# [{'Activity': 'Paddling',
#   'Case Number': '2018.06.25',
#   'Country': 'USA',
#   'Date': '25-Jun-18',
#   'Fatal': 'N',
#   'Injury': 'No injury to occupant, outrigger canoe and paddle damaged',
#   'Lat': 33.1959,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf',
#   'Lng': -117.3795,
#   'Location': 'Oceanside, San Diego County',
#   'Type': 'Boating',
#   'Year': '2018'},
#  {'Activity': 'Walking',
#   'Case Number': '2018.05.26.b',
#   'Country': 'USA',
#   'Date': '26-May-18',
#   'Fatal': 'N',
#   'Injury': 'Lower left leg bitten',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.05.26.b-High.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Unprovoked',
#   'Year': '2018'},
#  {'Activity': 'Standing',
#   'Case Number': '2018.05.26.a',
#   'Country': 'USA',
#   'Date': '26-May-18',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to foot',
#   'Lat': 29.2108,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.05.26.a-DaytonaBeach.pdf',
#   'Lng': -81.0228,
#   'Location': 'Daytona Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2018'},
#  {'Activity': 'Boogie boarding',
#   'Case Number': '2018.05.21',
#   'Country': 'USA',
#   'Date': '21-May-18',
#   'Fatal': 'N',
#   'Injury': 'Injuries to lower right leg and foot',
#   'Lat': 32.7868,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.05.21-deBoer.pdf',
#   'Lng': -79.7948,
#   'Location': 'Isle of Palms,  Charleston County',
#   'Type': 'Unprovoked',
#   'Year': '2018'},
#  {'Activity': 'Swimming',
#   'Case Number': '2018.05.13.b',
#   'Country': 'USA',
#   'Date': '13-May-18',
#   'Fatal': 'N',
#   'Injury': 'Severe bite to right forearm',
#   'Lat': 32.2163,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.05.13.b-Turrell.pdf',
#   'Lng': -80.7526,
#   'Location': 'Hilton Head Island, Beaufort County',
#   'Type': 'Unprovoked',
#   'Year': '2018'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.11.18',
#   'Country': 'USA',
#   'Date': '18-Nov-17',
#   'Fatal': 'N',
#   'Injury': 'Heel bitten',
#   'Lat': 27.9464,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.11.18-Anderson.pdf',
#   'Lng': -80.4956,
#   'Location': 'Floridana Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing ',
#   'Case Number': '2017.10.23.b',
#   'Country': 'USA',
#   'Date': '23-Oct-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 26.8798,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.10.23.b-Hartl.pdf',
#   'Lng': -80.0534,
#   'Location': 'Juno Beach, Palm Beach County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.25.b',
#   'Country': 'USA',
#   'Date': '25-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to lower left leg and foot',
#   'Lat': 32.5568,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.25.b-White.pdf',
#   'Lng': -93.8016,
#   'Location': 'Hanna Park, Jacksonville, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.24.b',
#   'Country': 'USA',
#   'Date': '24-Sep-17',
#   'Fatal': nan,
#   'Injury': 'Lacerations to right ankle, foot & toe',
#   'Lat': 40.9012,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.24.b-Behrend.pdf',
#   'Lng': -74.5143,
#   'Location': 'Rockaway',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.24.a',
#   'Country': 'USA',
#   'Date': '24-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Laceration to upper arm',
#   'Lat': 32.7254,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.24.a-FortWorth.pdf',
#   'Lng': -97.3208,
#   'Location': 'Fort Worth',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.20',
#   'Country': 'USA',
#   'Date': '20-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Minor lacerations to sole of left foot',
#   'Lat': 26.6503,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.20-Inniss.pdf',
#   'Lng': -80.4498,
#   'Location': 'Palm Beach County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.16.a',
#   'Country': 'USA',
#   'Date': '16-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 29.0964,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.16.a-Volusia.pdf',
#   'Lng': -80.937,
#   'Location': 'Ponce Inlet, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.13',
#   'Country': 'USA',
#   'Date': '13-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 29.0964,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.13-Loyd.pdf',
#   'Lng': -80.937,
#   'Location': 'Ponce Inlet, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.09.02.c',
#   'Country': 'USA',
#   'Date': '2-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to abdomen',
#   'Lat': 44.9,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.02.c-Maccarty.pdf',
#   'Lng': -89.7668,
#   'Location': 'Marathon, Monroe County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.09.02.b',
#   'Country': 'USA',
#   'Date': '2-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to foot',
#   'Lat': 26.1037,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.02.b-SouthPadre.pdf',
#   'Lng': -97.1647,
#   'Location': 'South Padre Island, Cameron County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.09.02.a',
#   'Country': 'USA',
#   'Date': '2-Sep-17',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to right hand',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.09.02.a-Elmore.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.07.29.c',
#   'Country': 'USA',
#   'Date': '29-Jul-17',
#   'Fatal': nan,
#   'Injury': 'Abrasions and cuts to sole of foot',
#   'Lat': 32.2163,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.07.29.c-Simatacolos.pdf',
#   'Lng': -80.7526,
#   'Location': 'Hilton Head Island, Beaufort County',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': nan,
#   'Case Number': '2017.07.23.b',
#   'Country': 'USA',
#   'Date': '23-Jul-17',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to hand',
#   'Lat': 50.5948,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.07.23.b-Smith.pdf',
#   'Lng': -1.2037,
#   'Location': 'Ventnor',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.07.20.c',
#   'Country': 'USA',
#   'Date': '20-Jul-17',
#   'Fatal': nan,
#   'Injury': 'Foot injured',
#   'Lat': 32.2163,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.07.20.c-Rogier.pdf',
#   'Lng': -80.7526,
#   'Location': 'Hilton Head Island, Beaufort County',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.07.14.b',
#   'Country': 'USA',
#   'Date': '14-Jul-17',
#   'Fatal': 'N',
#   'Injury': 'Pulled off board by shark but no injury',
#   'Lat': -42.4943,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.07.14.b-Washington.pdf',
#   'Lng': 171.1742,
#   'Location': 'South Beach, Westport, Grays Harbor County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Kayaking',
#   'Case Number': '2017.07.11',
#   'Country': 'USA',
#   'Date': '11-Jul-17',
#   'Fatal': 'N',
#   'Injury': 'No injury, kayak bitten',
#   'Lat': -17.8,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.07.11-Lawson.pdf',
#   'Lng': -63.1667,
#   'Location': 'Santa Cruz, Santa Cruz County',
#   'Type': 'Boating',
#   'Year': '2017'},
#  {'Activity': 'Fishing',
#   'Case Number': '2017.06.29',
#   'Country': 'USA',
#   'Date': '29-Jun-17',
#   'Fatal': nan,
#   'Injury': 'Arm injured by hook, not by a shark',
#   'Lat': 34.2085,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.29-Wrightsville.pdf',
#   'Lng': -77.7964,
#   'Location': 'Wrightsville Beach',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.06.10.a',
#   'Country': 'USA',
#   'Date': '10-Jun-17',
#   'Fatal': 'N',
#   'Injury': 'Laceration to left foot',
#   'Lat': 29.0964,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.10.a-Brock.pdf',
#   'Lng': -80.937,
#   'Location': 'Ponce Inlet, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Touching a shark',
#   'Case Number': '2017.05.30',
#   'Country': 'USA',
#   'Date': '30-May-17',
#   'Fatal': 'N',
#   'Injury': 'Right hand bitten by hooked shark PROVOKED INCIDENT',
#   'Lat': 33.0377,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.30-Higgins.pdf',
#   'Lng': -79.6131,
#   'Location': 'Awendaw, Charleston County',
#   'Type': 'Provoked',
#   'Year': '2017'},
#  {'Activity': 'Snorkeling',
#   'Case Number': '2017.05.06',
#   'Country': 'MEXICO',
#   'Date': '5-May-17',
#   'Fatal': 'Y',
#   'Injury': 'FATAL',
#   'Lat': -28.6685,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.06-Rozada.pdf',
#   'Lng': -65.7517,
#   'Location': 'Los Arbolitos, Cabo Pulmo',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.05.03',
#   'Country': 'USA',
#   'Date': '3-May-17',
#   'Fatal': nan,
#   'Injury': 'Laceration to thigh, likely caused by surfboard fin',
#   'Lat': 33.8807,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.03-Raab.pdf',
#   'Lng': -78.5122,
#   'Location': 'Sunset Beach, Orange County',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.04.29.d',
#   'Country': 'USA',
#   'Date': '29-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Major injury to posterior thigh',
#   'Lat': 9.7359,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.29.d-Ericson.pdf',
#   'Lng': -75.5263,
#   'Location': 'San Onofre, San Diego County ',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.04.29.b',
#   'Country': 'USA',
#   'Date': '29-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Left foot bitten',
#   'Lat': 32.6552,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.29.b-Dyar.pdf',
#   'Lng': -79.9404,
#   'Location': 'Folly Beach, Charleston County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Photo shoot',
#   'Case Number': '2017.04.26',
#   'Country': 'USA',
#   'Date': '26-Apr-17',
#   'Fatal': nan,
#   'Injury': 'Alleged laceration to left ankle',
#   'Lat': 18.8333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.05.26-Cavelli.pdf',
#   'Lng': 100.6667,
#   'Location': nan,
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.04.20',
#   'Country': 'USA',
#   'Date': '20-Apr-17',
#   'Fatal': nan,
#   'Injury': 'Laceration & puncture wounds to left foot',
#   'Lat': 33.4502,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.20-PawleysIsland.pdf',
#   'Lng': -79.3498,
#   'Location': 'Georgetown County',
#   'Type': 'Invalid',
#   'Year': '2017'},
#  {'Activity': nan,
#   'Case Number': '2017.04.17.b',
#   'Country': 'USA',
#   'Date': '17-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Minor bite to the foot',
#   'Lat': 29.2108,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.17.b-Volusia.pdf',
#   'Lng': -81.0228,
#   'Location': 'Daytona Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.04.13',
#   'Country': 'USA',
#   'Date': '13-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right foot',
#   'Lat': 32.5568,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.13-Perry.pdf',
#   'Lng': -93.8016,
#   'Location': 'Hanna Park, Jacksonville, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.04.12.b',
#   'Country': 'USA',
#   'Date': '12-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right foot',
#   'Lat': 29.8947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.12.b-Keyton.pdf',
#   'Lng': -81.3145,
#   'Location': 'St. Augustine',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.04.11',
#   'Country': 'USA',
#   'Date': '11-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Calf bitten',
#   'Lat': 29.2858,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.11-Oosterveld.pdf ',
#   'Lng': -81.0559,
#   'Location': 'Ormond Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Paddle boarding',
#   'Case Number': '2017.04.10.b',
#   'Country': 'USA',
#   'Date': '10-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Laceration to calf',
#   'Lat': 28.0684,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.10.b-Melbourne.pdf',
#   'Lng': -80.5603,
#   'Location': 'Melbourne Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.04.10.a',
#   'Country': 'USA',
#   'Date': '10-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left hand',
#   'Lat': 28.0684,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.10.a-Orr.pdf',
#   'Lng': -80.5603,
#   'Location': 'Melbourne Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.04.05',
#   'Country': 'USA',
#   'Date': '5-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Thigh nipped, minor injury',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.05-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.04.02.a',
#   'Country': 'USA',
#   'Date': '2-Apr-17',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to thighs',
#   'Lat': 30.3935,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.04.02.a-Taylor.pdf',
#   'Lng': -86.4958,
#   'Location': 'Destin, Okaloosa County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2017.03.27',
#   'Country': 'USA',
#   'Date': '27-Mar-17',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.03.27-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Swimming',
#   'Case Number': '2017.02.11',
#   'Country': 'USA',
#   'Date': '11-Feb-17',
#   'Fatal': 'N',
#   'Injury': 'Injury to hand',
#   'Lat': 28.0684,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.02.11-MelbourneBeach.pdf',
#   'Lng': -80.5603,
#   'Location': 'Melbourne Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': nan,
#   'Case Number': '2017.01.22',
#   'Country': 'USA',
#   'Date': '22-Jan-17',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to lower arm or hand',
#   'Lat': 27.6386,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.01.22-VeroBeach.pdf',
#   'Lng': -80.3973,
#   'Location': 'Vero Beach, Indian River County',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': nan,
#   'Case Number': '2017.01.13.a',
#   'Country': 'USA',
#   'Date': '13-Jan-17',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to hand',
#   'Lat': 27.2545,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2017.01.13.a-JensenBeach.pdf',
#   'Lng': -80.2298,
#   'Location': 'Jensen Beach',
#   'Type': 'Unprovoked',
#   'Year': '2017'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.12.11.a',
#   'Country': 'USA',
#   'Date': '11-Dec-16',
#   'Fatal': nan,
#   'Injury': 'Cuts to right ankle & foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.12.11.a-Garthwait.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Invalid',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.10.10',
#   'Country': 'USA',
#   'Date': '10-Oct-16',
#   'Fatal': 'N',
#   'Injury': 'Wounds to upper thigh and lower leg',
#   'Lat': 30.0191,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.10.10-Tanner.pdf',
#   'Lng': -90.1412,
#   'Location': 'Indian Beach, Ecola State Park, Clatsop County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.10.02',
#   'Country': 'USA',
#   'Date': '2-Oct-16',
#   'Fatal': 'N',
#   'Injury': 'Cuts to dorsal surface of left foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.10.02-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfng',
#   'Case Number': '2016.10.01',
#   'Country': 'USA',
#   'Date': '1-Oct-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injuries',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.10.01-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.09.18.c',
#   'Country': 'USA',
#   'Date': '18-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to thigh',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.c-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.09.18.b',
#   'Country': 'USA',
#   'Date': '18-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to hands',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.b-Luciano.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.09.18.a',
#   'Country': 'USA',
#   'Date': '18-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to lower leg',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.18.a-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Wading',
#   'Case Number': '2016.09.11',
#   'Country': 'USA',
#   'Date': '11-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to arm',
#   'Lat': 30.2275,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.11-PonteVedra.pdf',
#   'Lng': -81.3801,
#   'Location': 'Ponte Vedra, St. Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.09.07',
#   'Country': 'USA',
#   'Date': '7-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Severe lacerations to shoulder & forearm',
#   'Lat': 21.4694,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.07-Bagnol.pdf',
#   'Lng': -158.2175,
#   'Location': 'Makaha, Oahu',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Body boarding',
#   'Case Number': '2016.09.04',
#   'Country': 'USA',
#   'Date': '4-Sep-16',
#   'Fatal': 'N',
#   'Injury': 'Foot bitten',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.09.04-Moore.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.08.29.b',
#   'Country': 'USA',
#   'Date': '29-Aug-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.08.29.b-Cumiskey.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.08.29.a',
#   'Country': 'USA',
#   'Date': '29-Aug-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to ankle',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.08.29.a-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Wading',
#   'Case Number': '2016.08.25',
#   'Country': 'USA',
#   'Date': '25-Aug-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to ankle',
#   'Lat': 30.2275,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.08.25-Cassetty.pdf',
#   'Lng': -81.3801,
#   'Location': 'Ponte Vedra, St. Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.08.04',
#   'Country': 'USA',
#   'Date': '4-Aug-16',
#   'Fatal': 'N',
#   'Injury': 'Big toe bitten',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.04-Tyler.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.07.16.b',
#   'Country': 'USA',
#   'Date': '16-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to leg',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.16.b-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': nan,
#   'Case Number': '2016.07.16.a',
#   'Country': 'USA',
#   'Date': '16-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to toes',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.16.a-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Kite surfing',
#   'Case Number': '2016.07.15.b',
#   'Country': 'USA',
#   'Date': '15-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'No injury, board damaged',
#   'Lat': 25.8784,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.15.b-Frees.pdf',
#   'Lng': -80.1256,
#   'Location': 'Surfside, Orange County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.07.15.a',
#   'Country': 'USA',
#   'Date': '15-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to foot',
#   'Lat': 33.816,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.15.a-MyrtleBeach.pdf',
#   'Lng': -78.68,
#   'Location': 'North Myrtle Beach, Horry County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Fishing for squid',
#   'Case Number': '2016.07.08',
#   'Country': 'USA',
#   'Date': '8-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'No injury. Hull bitten, tooth fragment recovered',
#   'Lat': 36.9752,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.08-CapitolaBoat.pdf',
#   'Lng': -121.9533,
#   'Location': 'Capitola, Santa Cruz County',
#   'Type': 'Boating',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.07.06',
#   'Country': 'USA',
#   'Date': '6-Jul-16',
#   'Fatal': 'N',
#   'Injury': 'Buttocks, thigh, left hand & wrist injured',
#   'Lat': 28.0684,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.07.06-Njwoman.pdf',
#   'Lng': -80.5603,
#   'Location': 'Melbourne Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': nan,
#   'Case Number': '2016.06.27',
#   'Country': 'USA',
#   'Date': '27-Jun-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury',
#   'Lat': 32.7632,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.27-Sullivans.pdf',
#   'Lng': -79.8367,
#   'Location': "Sullivan's Island",
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.06.25',
#   'Country': 'USA',
#   'Date': '25-Jun-16',
#   'Fatal': 'N',
#   'Injury': 'Foot injured',
#   'Lat': 30.3344,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.25-AtlanticBeach.pdf',
#   'Lng': -81.3987,
#   'Location': 'Atlantic Beach, Emerald Isle, Carteret County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Floating',
#   'Case Number': '2016.06.21.b',
#   'Country': 'USA',
#   'Date': '21-Jun-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations and punctures to foot',
#   'Lat': 33.816,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.21.b-Schott.pdf',
#   'Lng': -78.68,
#   'Location': 'North Myrtle Beach, Horry County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Standing',
#   'Case Number': '2016.06.11',
#   'Country': 'USA',
#   'Date': '11-Jun-16',
#   'Fatal': 'N',
#   'Injury': 'Laceration to wrist',
#   'Lat': 30.3344,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.11-Bowen.pdf',
#   'Lng': -81.3987,
#   'Location': 'Atlantic Beach, Emerald Isle, Carteret County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.06.07',
#   'Country': 'USA',
#   'Date': '7-Jun-16',
#   'Fatal': nan,
#   'Injury': 'No injury, board damaged',
#   'Lat': 32.6552,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.07-Oneill.pdf',
#   'Lng': -79.9404,
#   'Location': 'Folly Beach, Charleston County',
#   'Type': 'Invalid',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.06.05.b',
#   'Country': 'USA',
#   'Date': '5-Jun-16',
#   'Fatal': 'N',
#   'Injury': 'Leg bitten',
#   'Lat': 29.475,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.06.05.b-Flagler.pdf',
#   'Lng': -81.127,
#   'Location': 'Flagler Beach, Flagler County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.05.29.b',
#   'Country': 'USA',
#   'Date': '29-May-16',
#   'Fatal': 'N',
#   'Injury': 'Injuries to arm and shoulder',
#   'Lat': 33.5995,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.29.b-Corona.pdf',
#   'Lng': -117.8725,
#   'Location': 'Corona Del Mar, Newport, Orange County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.05.29.a',
#   'Country': 'USA',
#   'Date': '29-May-16',
#   'Fatal': 'N',
#   'Injury': 'Injury to posterior right leg',
#   'Lat': 40.224,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.29.a-Neptune.pdf',
#   'Lng': -74.0478,
#   'Location': 'Neptune, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.05.22',
#   'Country': 'USA',
#   'Date': '22-May-16',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to thigh',
#   'Lat': 27.6386,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.22-Marcus.pdf',
#   'Lng': -80.3973,
#   'Location': 'Vero Beach, Indian River County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.05.21.b',
#   'Country': 'USA',
#   'Date': '21-May-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations and puncture wounds to foot and ankle',
#   'Lat': 59.8944,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.21.b-Magee.pdf',
#   'Lng': 30.2642,
#   'Location': 'St. Petersburg, Pinellas County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2016.05.18',
#   'Country': 'USA',
#   'Date': '18-May-16',
#   'Fatal': 'N',
#   'Injury': 'Ankle bitten',
#   'Lat': 30.2275,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.18-Wilson.pdf',
#   'Lng': -81.3801,
#   'Location': 'Ponte Vedra, St. Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Teasing a shark',
#   'Case Number': '2016.05.15',
#   'Country': 'USA',
#   'Date': '15-May-16',
#   'Fatal': 'N',
#   'Injury': 'Arm grabbed PROVOKED INCIDENT',
#   'Lat': 26.3587,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.05.15-Boca.pdf',
#   'Lng': -80.0831,
#   'Location': 'Boca Raton, Palm Beach County',
#   'Type': 'Provoked',
#   'Year': '2016'},
#  {'Activity': 'Surfing',
#   'Case Number': '2016.04.23',
#   'Country': 'USA',
#   'Date': '23-Apr-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.04.23-Beardall.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Snorkeling',
#   'Case Number': '2016.03.31',
#   'Country': 'USA',
#   'Date': '31-Mar-16',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left foot',
#   'Lat': 20.8123,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.03.31-Orr.pdf',
#   'Lng': -156.6214,
#   'Location': 'Olowalu, Maui',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': nan,
#   'Case Number': '2016.03.28.b',
#   'Country': 'USA',
#   'Date': '28-Mar-16',
#   'Fatal': nan,
#   'Injury': 'Minor injury to arm. Possibly caused by smalll nurse shark',
#   'Lat': 26.452,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.03.28.b-Kawa.pdf',
#   'Lng': -81.9481,
#   'Location': 'Fort Myers Beach, Lee County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Body surfing',
#   'Case Number': '2016.03.11',
#   'Country': 'USA',
#   'Date': '11-Mar-16',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right foot and ankle',
#   'Lat': 27.6386,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2016.03.11-Kenny.pdf',
#   'Lng': -80.3973,
#   'Location': 'Vero Beach, St. Lucie County',
#   'Type': 'Unprovoked',
#   'Year': '2016'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.11.15.b',
#   'Country': 'USA',
#   'Date': '15-Nov-15',
#   'Fatal': 'N',
#   'Injury': 'Leg injured',
#   'Lat': 26.6503,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.11.15.b-SRB.pdf',
#   'Lng': -80.4498,
#   'Location': 'Palm Beach, Palm Beach County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.12.23',
#   'Country': 'USA',
#   'Date': '7-Nov-15',
#   'Fatal': nan,
#   'Injury': 'Lower left leg injured',
#   'Lat': -38.1894,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.11.07-Underwood.pdf',
#   'Lng': 147.4241,
#   'Location': 'Paradise Beach, Melbourne, Brevard County',
#   'Type': 'Invalid',
#   'Year': '2015'},
#  {'Activity': 'Wading',
#   'Case Number': '2015.11.01.b',
#   'Country': 'USA',
#   'Date': '1-Nov-15',
#   'Fatal': 'N',
#   'Injury': 'Injury to right ankle/calf & hand',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.11.01.b-Kruse.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Body boarding',
#   'Case Number': '2015.10.28.a',
#   'Country': 'USA',
#   'Date': '28-Oct-15',
#   'Fatal': 'N',
#   'Injury': 'Lacerations & puncture wounds to right thigh, calf & ankle',
#   'Lat': -22.6138,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.28-Senensi.pdf',
#   'Lng': 27.328,
#   'Location': 'Malaka, Oahu',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.10.19',
#   'Country': 'USA',
#   'Date': '19-Oct-15',
#   'Fatal': 'N',
#   'Injury': 'Left foot bitten',
#   'Lat': 26.3184,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.19-Kirn.pdf',
#   'Lng': -80.0998,
#   'Location': 'Deerfield Beach, Broward County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Wading',
#   'Case Number': '2015.10.05.a',
#   'Country': 'USA',
#   'Date': '5-Oct-15',
#   'Fatal': 'N',
#   'Injury': 'Foot & hands bitten',
#   'Lat': 29.3669,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.05.a-Slaughter.pdf',
#   'Lng': -94.9669,
#   'Location': 'Galveston',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.10.04',
#   'Country': 'USA',
#   'Date': '4-Oct-15',
#   'Fatal': 'N',
#   'Injury': 'Severe lacerations to left hand',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.10.04-Tarasovic.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.09.29',
#   'Country': 'USA',
#   'Date': '29-Sep-15',
#   'Fatal': 'N',
#   'Injury': 'Laceration to heel, puncture wounds to dorsum of foot',
#   'Lat': 29.9189,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.09.29-Morrison.pdf',
#   'Lng': -81.2928,
#   'Location': 'Vilano Beach, St.  Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.09.20.d',
#   'Country': 'USA',
#   'Date': '20-Sep-15',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left ankle',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.09.20.d-NSB.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Photographing fish',
#   'Case Number': '2015.09.20.a',
#   'Country': 'USA',
#   'Date': '20-Sep-15',
#   'Fatal': 'N',
#   'Injury': 'Injury to right hand / wrist',
#   'Lat': 29.9189,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.09.20.a-Schiavo.pdf',
#   'Lng': -81.2928,
#   'Location': 'Vilano Beach, St.  Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.09.17',
#   'Country': 'USA',
#   'Date': '17-Sep-15',
#   'Fatal': 'N',
#   'Injury': 'Injury to right foot',
#   'Lat': 30.2947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.09.17-Liebetrau.pdf',
#   'Lng': -81.3931,
#   'Location': 'Jacksonville Beach, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': nan,
#   'Case Number': '2015.09.03',
#   'Country': 'USA',
#   'Date': '3-Sep-15',
#   'Fatal': 'N',
#   'Injury': 'Right foot bitten',
#   'Lat': 33.6891,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.09.03-Wagner.pdf',
#   'Lng': -78.8867,
#   'Location': 'Myrtle Beach, Horry County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.08.29.a',
#   'Country': 'USA',
#   'Date': '29-Aug-15',
#   'Fatal': 'N',
#   'Injury': "No injury, shark struk sufer's leg and his board",
#   'Lat': 35.3658,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.08.29.a-Phillips.pdf',
#   'Lng': -120.8499,
#   'Location': 'Morro Bay, San Luis Obispo County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': nan,
#   'Case Number': '2015.08.22.b',
#   'Country': 'USA',
#   'Date': '22-Aug-15',
#   'Fatal': nan,
#   'Injury': 'Wound to right lower leg',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.08.22.b-CocoaBeach.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Invalid',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.08.20',
#   'Country': 'USA',
#   'Date': '20-Aug-15',
#   'Fatal': 'N',
#   'Injury': 'Injuries to left calf, arm and hand',
#   'Lat': 33.551,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.08.20-Peyton.pdf',
#   'Lng': -79.0414,
#   'Location': 'Murrells Inlet, Georgetown County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Walking',
#   'Case Number': '2015.08.19',
#   'Country': 'USA',
#   'Date': '19-Aug-15',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right leg',
#   'Lat': 30.2947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.08.19-Szsarmack',
#   'Lng': -81.3931,
#   'Location': 'Jacksonville Beach, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Kayak Fishing',
#   'Case Number': '2015.08.18.b',
#   'Country': 'USA',
#   'Date': '18-Aug-15',
#   'Fatal': 'N',
#   'Injury': 'No injury, kayak bitten',
#   'Lat': 34.7333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.08.18.b-Lyon.pdf',
#   'Lng': -120.0343,
#   'Location': 'Santa Barbara County',
#   'Type': 'Boating',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.07.26.b',
#   'Country': 'USA',
#   'Date': '26-Jul-15',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to sole of foot',
#   'Lat': 29.2108,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.07.26.b-Warrilow.pdf',
#   'Lng': -81.0228,
#   'Location': 'Daytona Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Kayak Fishing',
#   'Case Number': '2015.07.23.b',
#   'Country': 'USA',
#   'Date': '23-Jul-15',
#   'Fatal': 'N',
#   'Injury': 'No injury to occupant. Kayak bitten by gaffed shark. PROVOKED '
#             'INCIDENT',
#   'Lat': 32.8473,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.07.23.b-Lorber.pdf',
#   'Lng': -117.2742,
#   'Location': 'La Jolla, San Diego County',
#   'Type': 'Provoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.07.10',
#   'Country': 'USA',
#   'Date': '10-Jul-15',
#   'Fatal': 'N',
#   'Injury': 'No injury, shark bumped & damaged board',
#   'Lat': 33.6603,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.07.10-Miskin.pdf',
#   'Lng': -117.9992,
#   'Location': 'Huntington Beach, Orange County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Treading water',
#   'Case Number': '2015.07.08',
#   'Country': 'USA',
#   'Date': '8-Jul-15',
#   'Fatal': nan,
#   'Injury': 'Laceration to back',
#   'Lat': 33.6603,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.07.08-Finney.pdf',
#   'Lng': -117.9992,
#   'Location': 'Huntington Beach, Orange County',
#   'Type': 'Invalid',
#   'Year': '2015'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.06.26.c',
#   'Country': 'USA',
#   'Date': '26-Jun-15',
#   'Fatal': nan,
#   'Injury': 'Minor lacerations to leg',
#   'Lat': 30.2947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.26.c-Jacksonville.pdf',
#   'Lng': -81.3931,
#   'Location': 'Jacksonville Beach, Duval County',
#   'Type': 'Invalid',
#   'Year': '2015'},
#  {'Activity': 'Standing',
#   'Case Number': '2015.06.26.a',
#   'Country': 'USA',
#   'Date': '26-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to foot',
#   'Lat': -42.4943,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.26.a-Donahue.pdf',
#   'Lng': 171.1742,
#   'Location': 'South Beach, Hunting Island State Park, Beaufort County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Body surfing?',
#   'Case Number': '2015.06.25',
#   'Country': 'USA',
#   'Date': '25-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Multiple lacerations to back',
#   'Lat': 41.4517,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.25-Avon.pdf',
#   'Lng': -82.0351,
#   'Location': 'Avon, Hatteras Island, Outer Banks, Dare County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.06.24.b',
#   'Country': 'USA',
#   'Date': '24-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to foot',
#   'Lat': 34.4271,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.24.b-Noyes.pdf',
#   'Lng': -77.5461,
#   'Location': 'Surf City',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.06.17',
#   'Country': 'USA',
#   'Date': '17-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to calf ',
#   'Lat': 29.1761,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.17-Simpson.pdf',
#   'Lng': -80.9828,
#   'Location': 'Daytona Beach Shores',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Wading',
#   'Case Number': '2015.06.14.b',
#   'Country': 'USA',
#   'Date': '14-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Arm amputated below shoulder',
#   'Lat': 33.9166,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.14.b-Treschel.pdf',
#   'Lng': -78.1611,
#   'Location': 'Oak Island, Brunswick County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Wading',
#   'Case Number': '2015.06.14.a',
#   'Country': 'USA',
#   'Date': '14-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Left arm amputated at elbow & severe injury to leg',
#   'Lat': 33.9166,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.14.a-Yow.pdf',
#   'Lng': -78.1611,
#   'Location': 'Oak Island, Brunswick County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Attempting to rescue a shark',
#   'Case Number': '2015.06.05',
#   'Country': 'USA',
#   'Date': '5-Jun-15',
#   'Fatal': 'N',
#   'Injury': 'Puncture wound to finger',
#   'Lat': 26.1223,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.06.05-FortLauderdale.pdf',
#   'Lng': -80.1434,
#   'Location': 'Fort Lauderdale',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Standing',
#   'Case Number': '2015.05.29.b',
#   'Country': 'USA',
#   'Date': '29-May-15',
#   'Fatal': 'N',
#   'Injury': 'Left foot bitten',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.29.b-Gilpin.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Wading',
#   'Case Number': '2015.05.29.a',
#   'Country': 'USA',
#   'Date': '29-May-15',
#   'Fatal': 'N',
#   'Injury': 'Minor lacerations to dorsum of right foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.29.a-Hatfield.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.05.24',
#   'Country': 'USA',
#   'Date': '24-May-15',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to lower left leg and ankle, shallow lacerations '
#             'to foot, deep laceration to Achilles tendon',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.24-Wheatro.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Surfing',
#   'Case Number': '2015.05.20',
#   'Country': 'USA',
#   'Date': '20-May-15',
#   'Fatal': 'N',
#   'Injury': '2 puncture wounds to  dorsum of left foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.20-Zaccaria.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': nan,
#   'Case Number': '2015.05.15',
#   'Country': 'USA',
#   'Date': '15-May-15',
#   'Fatal': 'N',
#   'Injury': 'Laceration to foot ',
#   'Lat': 32.7632,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.15-Sullivans.pdf',
#   'Lng': -79.8367,
#   'Location': "Sullivan's Island",
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Swimming',
#   'Case Number': '2015.05.07',
#   'Country': 'USA',
#   'Date': '7-May-15',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to lower left leg, ankle & foot',
#   'Lat': 28.32,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.05.07-Green.pdf',
#   'Lng': -80.6076,
#   'Location': 'Cocoa Beach, Brevard  County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Shark fishing',
#   'Case Number': '2015.01.27',
#   'Country': 'USA',
#   'Date': '27-Jan-15',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to calf by hooked shark PROVOKED INCIDENT',
#   'Lat': 20.8783,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.01.27-Pollard.pdf',
#   'Lng': -156.6825,
#   'Location': 'Lahaina',
#   'Type': 'Provoked',
#   'Year': '2015'},
#  {'Activity': 'Swimming after falling overboard',
#   'Case Number': '2015.01.08',
#   'Country': 'USA',
#   'Date': '8-Jan-15',
#   'Fatal': nan,
#   'Injury': 'During his 16-hour swim to shore, he was circled by a shark but '
#             'it did not injure him',
#   'Lat': 18.8333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.01.08-Konrad.pdf',
#   'Lng': 100.6667,
#   'Location': nan,
#   'Type': 'Invalid',
#   'Year': '2015'},
#  {'Activity': nan,
#   'Case Number': '2015.01.01',
#   'Country': 'USA',
#   'Date': '1-Jan-15',
#   'Fatal': 'N',
#   'Injury': 'Leg bitten',
#   'Lat': 43.254,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2015.01.01-Child.pdf',
#   'Lng': -77.5972,
#   'Location': 'Windsor Beach, Indian River County',
#   'Type': 'Unprovoked',
#   'Year': '2015'},
#  {'Activity': 'Stand-Up Paddleboarding',
#   'Case Number': '2014.10.22',
#   'Country': 'USA',
#   'Date': '22-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'No injury, paddleboard bitten',
#   'Lat': 20.785,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.22-Lawrence.pdf',
#   'Lng': -156.4656,
#   'Location': 'Kihei, Maui',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Stand-Up Paddleboarding',
#   'Case Number': '2014.10.20',
#   'Country': 'USA',
#   'Date': '20-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'No injury, paddleboard bitten',
#   'Lat': 20.8947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.20-Maui.pdf',
#   'Lng': -156.47,
#   'Location': 'Kahului, Maui',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Surfing',
#   'Case Number': '2014.10.18',
#   'Country': 'USA',
#   'Date': '18-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'No injury, surfboard bitten',
#   'Lat': 20.7964,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.18-Roberson.pdf',
#   'Lng': -156.5142,
#   'Location': 'Maalaea, South Maui',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Standing in inner tube',
#   'Case Number': '2014.10.14',
#   'Country': 'USA',
#   'Date': '14-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 32.2163,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.14-Bandy.pdf',
#   'Lng': -80.7526,
#   'Location': 'Hilton Head Island, Beaufort County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Body surfing or Boogie boarding',
#   'Case Number': '2014.10.12',
#   'Country': 'USA',
#   'Date': '12-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'Laceration to right hand/wrist',
#   'Lat': 28.0684,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.12-Melbourne.pdf',
#   'Lng': -80.5603,
#   'Location': 'Melbourne Beach, Brevard County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Surfing',
#   'Case Number': '2014.10.05.b',
#   'Country': 'USA',
#   'Date': '5-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'Foot bitten',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.05.b-Ross.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Surfing',
#   'Case Number': '2014.10.05.a',
#   'Country': 'USA',
#   'Date': '5-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'Foot bitten',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.05.a-Mantooth.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Kayaking',
#   'Case Number': '2014.10.03.b',
#   'Country': 'USA',
#   'Date': '3-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'No injury to occupant, shark/s holded  kayak',
#   'Lat': 34.7333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.03.b-Kayaks2.pdf',
#   'Lng': -120.0343,
#   'Location': 'Santa Barbara County',
#   'Type': 'Boating',
#   'Year': '2014'},
#  {'Activity': 'Kayaking ',
#   'Case Number': '2014.10.03.a',
#   'Country': 'USA',
#   'Date': '3-Oct-14',
#   'Fatal': 'N',
#   'Injury': 'No injury to occupant, shark/s holded  kayak',
#   'Lat': 34.7333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.03.a-Kayaks1.pdf',
#   'Lng': -120.0343,
#   'Location': 'Santa Barbara County',
#   'Type': 'Boating',
#   'Year': '2014'},
#  {'Activity': 'Surfing',
#   'Case Number': '2014.09.21',
#   'Country': 'USA',
#   'Date': '21-Sep-14',
#   'Fatal': 'N',
#   'Injury': 'Minor injury to left foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.09.21-Lefebvre.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Body surfing',
#   'Case Number': '2014.08.31',
#   'Country': 'USA',
#   'Date': '31-Aug-14',
#   'Fatal': 'N',
#   'Injury': 'Injury to left calf',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.08.31-Masterson.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2014'},
#  {'Activity': 'Surfing',
# ...
#   'Lng': -78.68,
#   'Location': 'North Myrtle Beach, Horry County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Surfing',
#   'Case Number': '2011.09.16',
#   'Country': 'USA',
#   'Date': '16-Sep-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to arm',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.09.16-Jorgensen.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Surfing',
#   'Case Number': '2011.09.02',
#   'Country': 'USA',
#   'Date': '2-Sep-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to ankle & foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.09.02-True.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Wading',
#   'Case Number': '2011.08.17.c.',
#   'Country': 'USA',
#   'Date': '17-Aug-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to foot',
#   'Lat': 33.9968,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.08.17.c-Aronian.pdf',
#   'Lng': -77.9072,
#   'Location': 'Kure Beach, New Hanover County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': nan,
#   'Case Number': '2011.08.17.b.',
#   'Country': 'USA',
#   'Date': '17-Aug-11',
#   'Fatal': nan,
#   'Injury': 'Abrasions to left hand',
#   'Lat': 34.2085,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.08.17.b-child.pdf',
#   'Lng': -77.7964,
#   'Location': 'Wrightsville Beach, New Hanover County',
#   'Type': 'Invalid',
#   'Year': '2011'},
#  {'Activity': 'Floating ',
#   'Case Number': '2011.08.16.b',
#   'Country': 'USA',
#   'Date': '16-Aug--2011',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to  lower right leg and foot',
#   'Lat': 18.425,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.08.16.b-Strunk.pdf',
#   'Lng': -65.8329,
#   'Location': ' Vieques',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Playing in the surf',
#   'Case Number': '2011.08.15',
#   'Country': 'USA',
#   'Date': '15-Aug-11',
#   'Fatal': 'N',
#   'Injury': 'Puncture wounds to foot',
#   'Lat': 33.6891,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.08.15-Varney.pdf',
#   'Lng': -78.8867,
#   'Location': 'Myrtle Beach, Horry County',
#   'Type': 'Invalid',
#   'Year': '2011'},
#  {'Activity': 'Wade Fishing',
#   'Case Number': '2011.07.25',
#   'Country': 'USA',
#   'Date': '25-Jul-11',
#   'Fatal': 'N',
#   'Injury': 'No injury, shark bit boot',
#   'Lat': 45.0464,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.07.25-Aubrey.pdf',
#   'Lng': -87.2971,
#   'Location': 'Egg Harbor, Atlantic County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Surf fishing',
#   'Case Number': '2011.07.13.b',
#   'Country': 'USA',
#   'Date': '13-Jul-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 26.1037,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.07.13.b-Paez.pdf',
#   'Lng': -97.1647,
#   'Location': 'South Padre Island, Cameron County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Playing in the surf',
#   'Case Number': '2011.06.26',
#   'Country': 'USA',
#   'Date': '26-Jun-08',
#   'Fatal': 'N',
#   'Injury': 'Ankle bitten',
#   'Lat': 34.4902,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.06.26-Cartwright.pdf',
#   'Lng': -77.4316,
#   'Location': 'North Topsail Beach, Onslow County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Jet skiing',
#   'Case Number': '2011.06.21',
#   'Country': 'USA',
#   'Date': '21-Jun-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to foot and ankle',
#   'Lat': 30.3002,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.06.21-McConnell.pdf',
#   'Lng': -87.4275,
#   'Location': 'Perdido Key, Escambia County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Spearfishing',
#   'Case Number': '2011.06.06.b',
#   'Country': 'USA',
#   'Date': '6-Jun-11',
#   'Fatal': 'N',
#   'Injury': 'No injury, minor damage to wetsuit',
#   'Lat': 32.8473,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.06.06.b-Schlaefli.pdf',
#   'Lng': -117.2742,
#   'Location': 'La Jolla, San Diego County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Wading',
#   'Case Number': '2011.06.06.a',
#   'Country': 'USA',
#   'Date': '6-Jun-11',
#   'Fatal': 'N',
#   'Injury': 'Puncture wound to calf',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.06.06.a-McIntosh.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Body surfing',
#   'Case Number': '2011.05.13.b',
#   'Country': 'USA',
#   'Date': '13-May-11',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot & ankle',
#   'Lat': 30.2397,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.05.13.b-Brown.pdf',
#   'Lng': -81.3856,
#   'Location': 'Ponte Vedra Beach, St Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Surfing',
#   'Case Number': '2011.05.13.a',
#   'Country': 'USA',
#   'Date': '13-May-11',
#   'Fatal': 'N',
#   'Injury': 'Minor injury; puncture wounds to calf',
#   'Lat': 29.2858,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.05.13.a-Bronson.pdf',
#   'Lng': -81.0559,
#   'Location': 'Ormond Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Fishing ',
#   'Case Number': '2011.05.10',
#   'Country': 'USA',
#   'Date': '10-May-11',
#   'Fatal': 'N',
#   'Injury': 'Laceration to arm by captive shark PROVOKED INCIDENT',
#   'Lat': 25.7743,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.05.10-Storch.pdf',
#   'Lng': -80.1937,
#   'Location': 'Miami',
#   'Type': 'Provoked',
#   'Year': '2011'},
#  {'Activity': 'Spearfishing',
#   'Case Number': '2011.04.26',
#   'Country': 'USA',
#   'Date': '26-Apr-11',
#   'Fatal': 'N',
#   'Injury': 'Calf bitten',
#   'Lat': 26.7753,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.04.26-Seagrich.pdf',
#   'Lng': -80.0581,
#   'Location': 'Riviera Beach, Palm Beach County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Surfing ',
#   'Case Number': '2011.04.22',
#   'Country': 'USA',
#   'Date': '22-Apr-11',
#   'Fatal': 'N',
#   'Injury': 'Minor puncture wounds',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.04.22-RonWhite.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Swimming',
#   'Case Number': '2011.03.21.b',
#   'Country': 'MEXICO',
#   'Date': '21-Mar-11',
#   'Fatal': 'N',
#   'Injury': 'Right foot bitten',
#   'Lat': 18.8333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.03.21.b-Masternak.pdf',
#   'Lng': 100.6667,
#   'Location': nan,
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Shark fishing on the Ricardo Astorga',
#   'Case Number': '2011.02.04.R',
#   'Country': 'MEXICO',
#   'Date': 'Reported 04-Feb-2011',
#   'Fatal': 'N',
#   'Injury': 'Left foot bitten PROVOKED INCIDENT',
#   'Lat': 20.3433,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.02.04.R-Camacho.pdf',
#   'Lng': -77.1167,
#   'Location': 'Manzanillo, Revillagigedo Islands',
#   'Type': 'Provoked',
#   'Year': '2011'},
#  {'Activity': 'Swimming',
#   'Case Number': '2011.01.31',
#   'Country': 'MEXICO',
#   'Date': '31-Jan-11',
#   'Fatal': 'N',
#   'Injury': 'Leg, forearm & hand severely bitten',
#   'Lat': 21.1743,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2011.01.31-Moore.pdf',
#   'Lng': -86.8466,
#   'Location': 'Cancun',
#   'Type': 'Unprovoked',
#   'Year': '2011'},
#  {'Activity': 'Snorkeling',
#   'Case Number': '2010.11.19',
#   'Country': 'USA',
#   'Date': '19-Nov-10',
#   'Fatal': 'N',
#   'Injury': 'Head bitten by netted shark PROVOKED INCIDENT',
#   'Lat': 18.8333,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.11.19-Pollock.pdf',
#   'Lng': 100.6667,
#   'Location': nan,
#   'Type': 'Provoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.10.28',
#   'Country': 'USA',
#   'Date': '28-Oct-10',
#   'Fatal': 'N',
#   'Injury': 'No injury to surfer',
#   'Lat': 43.7667,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.10.28.a-SethMead.pdf',
#   'Lng': 11.25,
#   'Location': 'Florence',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Body boarding',
#   'Case Number': '2010.10.22',
#   'Country': 'USA',
#   'Date': '22-Oct-10',
#   'Fatal': 'Y',
#   'Injury': 'FATAL',
#   'Lat': -38.5133,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.10.22-Ransom.pdf',
#   'Lng': 145.2997,
#   'Location': 'Surf Beach, Vandenberg AFB, Santa Barbara County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Swimming',
#   'Case Number': '2010.09.07',
#   'Country': 'USA',
#   'Date': '7-Sep-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left wrist',
#   'Lat': 29.8947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.09.07-Whitworth.pdf',
#   'Lng': -81.3145,
#   'Location': "St. Augustine, St. John's County",
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.09.04',
#   'Country': 'USA',
#   'Date': ' 04-Sep-2010',
#   'Fatal': 'N',
#   'Injury': 'No injury, shark charged surfboard',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.09.04-Kerr.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.09.03.b',
#   'Country': 'USA',
#   'Date': '3-Sep-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right  hand ',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.09.03.b-Coffman.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.09.03.a',
#   'Country': 'USA',
#   'Date': '3-Sep-10',
#   'Fatal': 'N',
#   'Injury': 'Left thigh bitten',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.09.03.a-Heald.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach, Volusia County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Swimming',
#   'Case Number': '2010.08.05',
#   'Country': 'USA',
#   'Date': '5-Aug-10',
#   'Fatal': nan,
#   'Injury': 'Minor abrasions to legs when she was lifted on the back of a '
#             'large marine animal',
#   'Lat': 28.9492,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.08.05-Fischman.pdf',
#   'Lng': -80.8378,
#   'Location': 'Bethune Beach, Volusia County',
#   'Type': 'Invalid',
#   'Year': '2010'},
#  {'Activity': 'Standing',
#   'Case Number': '2010.07.25',
#   'Country': 'USA',
#   'Date': '25-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right lower leg',
#   'Lat': 32.7868,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.25-Stamm.pdf',
#   'Lng': -79.7948,
#   'Location': 'Isle of Palms, Charleston County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.07.23',
#   'Country': 'USA',
#   'Date': '23-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Left foot bitten',
#   'Lat': 30.2947,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.23-Schulz.pdf',
#   'Lng': -81.3931,
#   'Location': 'Jacksonville Beach, Duval County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Swimming',
#   'Case Number': '2010.07.19',
#   'Country': 'USA',
#   'Date': '19-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Minor lacerations to left calf',
#   'Lat': 33.6891,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.19-Myers.pdf',
#   'Lng': -78.8867,
#   'Location': 'Myrtle Beach',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Swimming',
#   'Case Number': '2010.07.17.b',
#   'Country': 'USA',
#   'Date': '17-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to right forearm',
#   'Lat': 34.2085,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.17.b-Parker.pdf',
#   'Lng': -77.7964,
#   'Location': 'Wrightsville Beach, New Hanover County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.07.17.a',
#   'Country': 'USA',
#   'Date': '17-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Minor lacerations to right foot',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.17.a-Johnston.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Fishing',
#   'Case Number': '2010.07.16.a',
#   'Country': 'USA',
#   'Date': '16-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Leg bitten',
#   'Lat': 29.3669,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.16.a-Gauzer.pdf',
#   'Lng': -94.9669,
#   'Location': 'Galveston',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Fishing',
#   'Case Number': '2010.07.11',
#   'Country': 'USA',
#   'Date': '11-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Small laceration to forearm from netted shark  PROVOKED INCIDENT',
#   'Lat': 26.192,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.11-Lauderdale-fisherman.pdf',
#   'Lng': -80.0964,
#   'Location': 'Lauderdale-by-the-Sea, Broward County',
#   'Type': 'Provoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.07.02.b',
#   'Country': 'USA',
#   'Date': '2-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'Laceration to left foot',
#   'Lat': 35.1428,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.02.b-Crane.pdf',
#   'Lng': -120.6413,
#   'Location': 'Pismo Beach, San Luis  Obispo County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Stand-Up Paddleboarding',
#   'Case Number': '2010.07.02.a',
#   'Country': 'USA',
#   'Date': '2-Jul-10',
#   'Fatal': 'N',
#   'Injury': 'No injury, board bumped by shark',
#   'Lat': 37.8195,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.07.02.a-Bull.pdf',
#   'Lng': -81.9987,
#   'Location': 'Dog Patch, San Onofre',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Boogie Boarding',
#   'Case Number': '2010.06.10',
#   'Country': 'USA',
#   'Date': '10-Jun-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left calf and foot',
#   'Lat': 30.3322,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.06.10-Mayo-Foster.pdf',
#   'Lng': -81.6556,
#   'Location': 'Jacksonville',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surfing',
#   'Case Number': '2010.06.00',
#   'Country': 'USA',
#   'Date': 'Jun-10',
#   'Fatal': 'N',
#   'Injury': 'Lacerations to left foot',
#   'Lat': 30.2397,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.06.00-Searcy.pdf',
#   'Lng': -81.3856,
#   'Location': 'Ponte Vedra Beach, St Johns County',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Wading',
#   'Case Number': '2010.05.01',
#   'Country': 'USA',
#   'Date': '1-May-10',
#   'Fatal': 'N',
#   'Injury': 'Minor puncture wounds to right ankle',
#   'Lat': 29.0258,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.05.01-Dubois.pdf',
#   'Lng': -80.927,
#   'Location': 'New Smyrna Beach',
#   'Type': 'Unprovoked',
#   'Year': '2010'},
#  {'Activity': 'Surf fishing / wading',
#   'Case Number': '2010.02.06.a',
#   'Country': 'USA',
#   'Date': '6-Feb-10',
#   'Fatal': 'N',
#   'Injury': 'Leg bitten while trying to free a hooked shark PROVOKED INCIDENT',
#   'Lat': 26.7753,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.02.06.a-RivieraBeach.pdf',
#   'Lng': -80.0581,
#   'Location': 'Riviera Beach',
#   'Type': 'Provoked',
#   'Year': '2010'},
#  {'Activity': 'Kite Boarding',
#   'Case Number': '2010.02.03',
#   'Country': 'USA',
#   'Date': '3-Feb-10',
#   'Fatal': 'Y',
#   'Injury': 'FATAL',
#   'Lat': 27.1976,
#   'Link': 'http://sharkattackfile.net/spreadsheets/pdf_directory/2010.02.03-Schafer.pdf',
#   'Lng': -80.2528,
#   'Location': 'Stuart, Martin County',
#   'Type': 'Unprovoked',
#   'Year': '2010'}]

# %%
with open("coordinates.json", "w") as outfile:
    json.dump(geoCoordinates, outfile)

# %%
#geoCoordinates.to_json("location.json")
geoDB = pd.DataFrame(geoCoordinates)
geoDB.to_csv("location.csv")
